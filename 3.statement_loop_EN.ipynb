# %% [markdown]
# # Week 3 - Conditional Statements and Loops

# %% [markdown]
# Created By Junyeong Ahn

# %% [markdown]
# **Goal 1**: Master Python's conditional statement -- the if statement.
#
# **Goal 2**: Master Python's loops -- while and for.

# %% [markdown]
# ## 1.If

# %% [markdown]
# ### Basic structure of an if statement

# %% [markdown]
# Imagine the following situation.
#
# `"If I have money, I take a taxi; if I don't, I walk."`
#
# This is one of those situations any of us could be in. Programming is also done by people, so just like the sentence above, there are cases where we need to evaluate a given condition and then act accordingly. The construct used in programming to evaluate a condition and execute the matching action is exactly the **if statement**.
#
# The situation above can be expressed in Python as follows.

# %%
money = "no"

if money == "yes":
    print("Take a taxi")
else,
    print("Walk")

# Take a taxi

# %%
money = False

if money:
    print("Take a taxi")
else:
    print("Walk")

# %% [markdown]
# - Code that doesn't strictly follow Python syntax but roughly expresses what you want to implement (like the example above) is called **pseudocode**.

# %% [markdown]
# In an if statement, the "condition" is an expression that evaluates to True or False.
#
# In the taxi example above, the condition is `money`.

# %%
money = False


if money:
  print("Money money")

# %% [markdown]
# ### What's a Condition Statement?

# %% [markdown]
# Comparison operators below all return a Bool value, which makes them one of the most common expressions you'll see inside an if condition.
#
# ![image.png](data:image/png;base64,...)

# %%
if 'Seojun' == 'Justin':
  print("I am Justin")

# %%
if 155 != '155':
  print("We are different")

# %% [markdown]
# ### Indentation

# %% [markdown]
# When writing an if statement, every line that belongs to the if block -- starting from the line right below `if condition:` -- must be indented.
#
#  As you can see below, when the condition is true, `statement_to_run_1` is indented, and `statement_to_run_2` and `statement_to_run_3` are also indented.

# %%
if condition:
    statement_to_run_1
    statement_to_run_2
    statement_to_run_3

# %% [markdown]
# Writing it like below produces an error, because `statement_to_run_2` is not indented.

# %%
if condition:
    statement_to_run_1
statement_to_run_2
    statement_to_run_3

# %%
money = True
if money:
    print("Take a taxi")
print("and")
    print("go")

# %% [markdown]
# ### Try It! 1

# %% [markdown]
# Express the sentence
# "If I have at least 3000 won, I take a taxi; otherwise I walk."
# as Python code.

# %%
money= 4000

if money >= 3000:
    print("sdfasdf")
else:
    print("asdf")

# %%
money = "9000won"

if int( money[:-3] ) > 2000:
    print("asdfasdf")
else:
    print("no")

# %%
money > 3000 (x)
money > "3000won" (x)

# %%
int( money[:-3] )

# %% [markdown]
# ### And, or and not

# %% [markdown]
# Other operators commonly used to evaluate conditions are `and`, `or`, and `not`. Each of them works as follows.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# true: 1, false: 0 / other numbers are NOT treated as boolean.

# %%
bool(False or 1)

# %%
(not (False and True) )  != (1 and 2)

# %%
'' and 8

# %%
0 == False

# %% [markdown]
# Let's look at how the `or` operator is used through the next example.
#
# ```"If I have at least 3000 won OR I have a card, take a taxi; otherwise walk."```

# %%
money = 2000
card = True

# Write further codes

if (money >= 3000) or (card == True) :
    print("take a taxi")
else:
    print("walk")

# %%
True and True

(1 == 1) == (2 == 2)

# %% [markdown]
# `and` and `or` can also be written using the symbols `&` and `|` respectively.

# %% [markdown]
# Actually, `&` and `|` were already introduced back in Week 2 - Set as the symbols for intersection and union.

# %%
1 & 2

# %%
1 and 2

# %%
if (5 == 5) & (11 != 10):
  print("Both statements are correct.")

# %%
if (5 == 7) | (5 == 5):
  print("At least one of the statements must be correct.")

# %% [markdown]
# ### In and not in

# %% [markdown]
# On top of that, Python provides some interesting conditional expressions you don't easily see in other programming languages.
#
# They are the following.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In particular, we already learned last week that `in` can be used to check whether something is among the keys of a dictionary.

# %% [markdown]
# If you remember that the English word "in" means "inside of", the next example will be easy to understand.

# %%
# 1 in [1, 2, 3]


1 not in [1, 2, 3]

# %%
'a' in ('a', 'b', 'c')

# 'j' not in 'python'

# %%
'a' in {'a', 'b'}

# %% [markdown]
# Now let's apply `in` to the taxi example we have been using.
#
# ```"If there is money in my pocket, take a taxi; otherwise walk."```

# %%
Pocket = ['paper', 'cellphone', 'money']

# Write further codes

if 'money' in Pocket: # check whether the element 'money' is in the variable (list) Pocket
    print('take a taxi')

else:
    print('walk')

# %% [markdown]
# ### What if you want the conditional to do nothing?

# %% [markdown]
# Sometimes, when you define what to do depending on whether a condition is True or False, you want one branch to do absolutely nothing.
#
# Look at the next example.
#
# ```"If there is money in my pocket, do nothing; if there is no money in my pocket, take out a card."```
#
# The keyword used in this case is **pass**. Let's implement the example above using `pass`.

# %%
pocket = ['paper', 'money', 'cellphone']

if 'money' in pocket:
    pass

else:
    print("Take out a card")


# ->

# if 'money' not in pocket:
#     print("Take out a card")

# %%
if (1 == 1):
    pass
print("yes")
print("hi")

# %% [markdown]
# Because the string `'money'` is in the `pocket` list, the line `pass` (right after the `if`) is executed and no result is shown.

# %% [markdown]
# Alternatively, you can do something like the following, but it's less efficient than `pass`.

# %%
pocket = ['paper', 'money', 'cellphone']

if 'money' in pocket:
    name = 5
     
else:
    print("Take out a card")

# %% [markdown]
# ### Elif

# %% [markdown]
# If and else can be illustrated as follows.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Then, if we put another if/else under `else`, we can write code like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = ?

if x < -100 :
  print("Do A")

else : # all the cases within the range from -100 to infinity
  
  if (-100 <= x) and (x < 100) :
    print("Do B")

  else : # all the cases within the range from 100 to infinity
    print("Do C")

# %% [markdown]
# Even at a glance it's hard to read and feels cluttered. To resolve this complexity, Python provides `elif`, which lets you check multiple conditions cleanly.
#
# Using `elif`, the example above can be rewritten as follows.

# %%
x = ?

if x < -100 :
  print("Do A")

elif (-100 <= x) and (x < 100) :
  print("Do B")

else : # all the cases within the range from 100 to infinity
  print("Do C")

# %% [markdown]
# In other words, `elif` runs when the previous condition was False. The basic structure when using `if`, `elif`, and `else` together is as follows.

# %%
If <condition>:
    <statement_1> 
    <statement_2>
    ...
elif <condition>:
    <statement_1>
    <statement_2>
    ...
elif <condition>:
    <statement_1>
    <statement_2>
    ...
...
else:
   <statement_1>
   <statement_2>
   ...

# %%
x = -1293013

if -int('inf') < x < -1000000:
    print("Welcome")

elif -1000000 < x < -100000:
    print("hi")

elif -100000 < x < 100000:

elif .

..


else:
    dfas

# %% [markdown]
# As you can see above, you can use as many `elif` clauses as you like.

# %% [markdown]
# ### Advanced - Conditional Expression

# %% [markdown]
# Look at the following code.

# %%
if score >= 60:
    message = "success"
else:
    message = "failure"

# %% [markdown]
# The code above assigns the string `"success"` to `message` if `score` is at least 60, and `"failure"` otherwise.
#
# Using Python's conditional expression, the same code can be written more concisely as follows.

# %%
message =           "success"     if score >= 60        else "failure"

# %% [markdown]
# A conditional expression is defined as follows.
#
# > variable = ```value_if_true if condition else value_if_false```
#
# Conditional expressions are great for readability and very handy because they fit on a single line.

# %% [markdown]
# ## 2.While Loop

# %% [markdown]
# ### Basic structure of a while loop

# %% [markdown]
# When you need to execute statements repeatedly, you use a `while` loop. That's why `while` is also called a loop (or repeating) statement.
#
# The basic structure of a while loop is shown below.

# %%
while <condition>:
    <statement_1>
    <statement_2>
    <statement_3>
    ...

# %% [markdown]
# A while loop repeatedly executes the statements inside it as long as the condition is True.
#
# If we turn the saying "There is no tree that won't fall after ten swings" into a Python program, it would look like this.

# %%
i = 0
while True:
    print("hello")
    i += 1
    
    if i == 100:
        break

# %%
treeHit = 0
while treeHit < 10:

    treeHit = treeHit +1
    print("Hit the tree %d time(s)." % treeHit)

    if treeHit == 10:
        print("The tree falls.")


#...
#Hit the tree 1 time(s).
#Hit the tree 2 time(s).
#Hit the tree 3 time(s).
#Hit the tree 4 time(s).
#Hit the tree 5 time(s).
#Hit the tree 6 time(s).
#Hit the tree 7 time(s).
#Hit the tree 8 time(s).
#Hit the tree 9 time(s).
#Hit the tree 10 time(s).
#The tree falls.

# %% [markdown]
# In the example above, the while loop's condition is `treeHit < 10`. That is, the statements inside the while loop keep running while `treeHit` is less than 10. Looking at the body of the loop, the very first statement **`treeHit = treeHit + 1`** keeps **incrementing `treeHit` by 1**.
#
# It then prints a message saying the tree has been hit `treeHit` times, and once `treeHit` becomes 10, it prints `"The tree falls."`.
#
# After that, the condition `treeHit < 10` becomes False and the loop exits.

# %% [markdown]
# > `treeHit = treeHit + 1` is a technique used very often in programming. It's used to increase `treeHit` by 1, and you can also write it as `treeHit += 1` -- this is called increment.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Building a while loop

# %% [markdown]
# Now let's build an example that lets the user pick one of several options. First, create a multi-line string called `prompt` as follows.

# %%
prompt = """
1. Add
2. Del
3. List
4. Quit
Enter number: """

# %%
print(prompt)
# Out:
# 1. Add
# 2. Del
# 3. List
# 4. Quit
# Enter number:

# %% [markdown]
# Next, assign 0 to the variable `number` first. If you don't initialize the variable beforehand, the upcoming while-loop condition `number != 4` will raise an error saying the variable doesn't exist.

# %%
number = 0
while number != 4:

    print(prompt)
    number = int(input())
# Out:
# 1. Add
# 2. Del
# 3. List
# 4. Quit
# Enter number:

# %% [markdown]
# ### How to escape the loop

# %% [markdown]
# A while loop keeps running its body as long as the condition is True.
#
# But sometimes you want to forcibly break out of a while loop.
#
# <br><br>
#
# Think about a coffee vending machine. As long as there is enough coffee inside, putting in a coin gives you coffee.
#
# But for the machine to work properly, it has to constantly check how much coffee is left.
#
#  If the coffee runs out, sales must stop and a "Sold Out" message must be shown to the user.
#
# <br><br>What forcibly stops sales like this is exactly the **break** statement.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
coffee = 10
money = 300
while money : # runs forever

    print("Money received, dispensing coffee.")

    coffee = coffee -1

    print("Coffee remaining: %d." % coffee) # Do you remember what formatting is?

    if coffee == 0:
      
        print("Coffee is sold out. Stopping sales.")
        break

# %%
coffee = 10
money = 300
while money: # runs forever

    print("Money received, dispensing coffee.")

    coffee = coffee -1

    print("Coffee remaining: %d." % coffee) # Do you remember what formatting is?

    if coffee == 0:
      
        print("Coffee is sold out. Stopping sales.")
        break

# %% [markdown]
# ### How to get back to the first line of a while loop

# %% [markdown]
# As statements inside a while loop run, the input condition is checked, and the loop is exited if the condition is no longer satisfied.
#
# But while programming, sometimes you want to skip the rest of the body and jump back to the very top of the while loop (the condition) without exiting it. The keyword used for this is `continue`.<br><br>
#
# Suppose you want to print only the odd numbers from 1 to 10 using a while loop. What would be a good approach?

# %%
a = 0

while a < 10:

    a = a + 1
    if a % 2 == 0: continue # for a single-line statement, you can write it on the same line after the colon.
    
    print(a)

# %% [markdown]
# The example above prints only odd numbers from 1 to 10.
#
# `a` keeps increasing by 1 while `a` is less than 10.
#
# `if a % 2 == 0` (i.e. when `a` divided by 2 has remainder 0) is True when `a` is even.
# <br><br>
# In other words, when `a` is even, the `continue` statement runs.
#
# The `continue` statement sends control back to the very top of the while loop (to the condition `a < 10`). So in the example above, when `a` is even, the `print(a)` line will not be executed.

# %% [markdown]
# ### Infinite Loop

# %% [markdown]
# An infinite loop means a loop that repeats forever. Almost every general-purpose program we use relies on the concept of an infinite loop somewhere -- that's how often it's used.

# %%
while True: 
    statement_to_run_1 
    statement_to_run_2
    ...

# %% [markdown]
# Since the while-loop condition is `True`, it is always satisfied. Therefore the statements inside the while loop will execute forever.
#
# Below is an example of an infinite loop.

# %%
while True:
    print("You have to press Ctrl+M+I to escape the while loop.")

#You have to press Ctrl+M+I to escape the while loop.
#You have to press Ctrl+M+I to escape the while loop.
#You have to press Ctrl+M+I to escape the while loop.
#....

# %% [markdown]
# ### Try It!

# %% [markdown]
# Using a while loop, write code that prints 1, 3, 6, 10, 15 in order.

# %% [markdown]
# ## 3.For Loop

# %% [markdown]
# The construct that best showcases Python's intuitive nature is the `for` loop. Like the `while` loop, the `for` loop is a loop construct, but it has the great advantage that its structure is very easy to read at a glance. Mastering the `for` loop will make programming feel fun.

# %% [markdown]
# ### Basic structure of a for loop

# %%
for variable in list (or tuple, or string): # iterable object: an object you can iterate over
    statement_to_run_1
    statement_to_run_2
    ...

# %%
for joonsung in 'ahnjunyeong':
    print(joonsung)

# %%
x = 1

while x < 19:
    x += 1

# %%
print(x)

# %%
for uu in [1, 2, 3, 19]:
    print(uu)

print(uu)

# %%
count = 0
for char in 'GCCCGCCCGCCCGCCGCCGCCG':
    if char == 'C':
        count += 1

# %% [markdown]
# Each element of the list, tuple, or string -- from the first to the last -- is assigned to the variable in turn, and `statement_to_run_1`, `statement_to_run_2`, etc. are then executed.

# %% [markdown]
# **1. Typical for loop**

# %%
test_list = ['one', 'two', 'three'] 
for i in test_list: 
    print(i)

# %% [markdown]
# The first element `'one'` of the list `['one', 'two', 'three']` is assigned to `i` first, then `print(i)` runs.
#
# Next, `'two'` is assigned to `i` and `print(i)` runs again, and this repeats up to the last element of the list.

# %% [markdown]
# **2. Various uses of for loops**

# %%
a = [(1,2), (3,4), (5,6)]

# 1
for ele in a:
    print(ele[0] + ele[1])

# 2
for (genius, babo) in a:
    print(genius + babo)

# for (first, last) in a:
#     print(first + last)

# %%
x = 0
a = [ ['1', '2', '4'], ['1', '4', '5'] ]

for _ in a:
    x += int(''.join(_))

print(x)

# %%
i = 0

# i = i + 2
i += 2

# %% [markdown]
# In the example above, because each element of the list `a` is a tuple, each element is automatically unpacked into the variables `(first, last)`.

# %% [markdown]
# **3. Applying the for loop**

# %% [markdown]
# A total of 5 students took an exam. A score of 60 or above is a pass; otherwise, it's a fail. Show whether each student passed or failed.

# %% [markdown]
# First, let's express the 5 students' exam scores as a list.

# %%
marks = [90, 25, 67, 45, 80]

# %% [markdown]
# Student #1 scored 90, and student #5 scored 80.
#
# Let's write a program that goes through these scores in order and reports whether each student passed or failed.

# %%
marks = [90, 25, 67, 45, 80]

number = 0 
for mark in marks: 
    number += 1 
    if mark >= 60: 
        print("Student #%d passed." % number)
    else: 
        print("Student #%d failed." % number)

# %% [markdown]
# We used the variable `number` to give each student a number.
#
# We pull each score from the `marks` list one by one, assign it to `mark`, and run the statements inside the for loop.
#
# Each time the for loop runs once, `number` increases by 1.

# %% [markdown]
# ### Continue

# %% [markdown]
# The **`continue` statement** that we saw in the `while` loop can also be used in a `for` loop.
#
# That is, if `continue` is reached while running statements inside a for loop, control jumps back to the start of the for loop.
#
# Reusing the for-loop application example from above, let's write a program that sends a congratulations message to people who scored 60 or above and says nothing to the rest.

# %%
marks = [90, 25, 67, 45, 80]

number = 0 
for mark in marks: 
    number = number +1 
    if mark < 60:
        continue
     
    print("Congratulations, student #%d. You passed. " % number)

# %%
for mark in ['1', '2', '3']:
    print(mark)

# %% [markdown]
# If a student scored 60 or below, `mark < 60` is True and `continue` runs. So the `print` statement that outputs the congratulations message is skipped and we go back to the start of the for loop.

# %% [markdown]
# ### Range function

# %% [markdown]
# A `for` loop is often used together with the `range` function, which automatically generates a list of numbers. Below is a simple usage of `range`.

# %%
for i in range(19):
    print(i)

# %%
a = range(0, 10, 2)

list(a)

# type(a)

# %% [markdown]
# `range(10)` creates a `range` object containing the numbers from 0 up to (but not including) 10.

# %% [markdown]
# To specify a start and end, you use the form **`range(start, stop)`**, where the end is not included -- same as in slicing.

# %%
a = range(1, 11)

a

# %% [markdown]
# Just like with slicing, the `range` function also lets you adjust the **step size**.

# %%
a = range(1, 11, 2)

# print(a)
print(list(a))

# %%
a = [1, 234, 2,34,1324,1,41,413,4,123,12,412]




for idx in range(len(a)):
     
    print(f"The value at index {idx} is {a[idx]}")

# %%
a = [1, 234, 2,34,1324,1,41,413,4,123,12,412]
print(len(a))


for i in range(len(a)):
    if i % 3 == 0:
        
        a[i] = a[i] * 3

print(a)

# %% [markdown]
# ### Range function examples

# %% [markdown]
# Using `for` and the `range` function, we can easily compute the sum from 1 to 10 like this.

# %%
add = 0 
for i in range(1, 11): 
    add = add + i 

print(add)

# %% [markdown]
# `range(1, 11)` is an object containing the numbers 1 through 10 (i.e. >= 1 and < 11).
#
# So in the example above, the variable `i` takes on each value from 1 to 10 in turn, and `add = add + i` runs repeatedly, leaving `add` equal to 55 in the end.

# %% [markdown]
# We can also rewrite the earlier "60 or above is a pass" example using the `range` function as follows.

# %%
marks = [90, 25, 67, 45, 80]
for number in range(len(marks)):
    if marks[number] < 60: 
        continue
    print("Congratulations, student #%d. You passed." % (number+1))

# %% [markdown]
# `len` is a function that returns the number of elements in a list. So `len(marks)` is 5, and `range(len(marks))` is `range(5)`.
#
# The variable `number` takes on the values 0 through 4 in turn, and `marks[number]` is therefore 90, 25, 67, 45, 80 in turn.

# %% [markdown]
# ### Try It! - Multiplication Table

# %% [markdown]
# Using `for` and `range`, you can print the multiplication table in just 4 lines of source code.
#
# Try typing it in carefully, paying attention to the indentation.

# %%
for i in range(1,13):
    for j in range(1,13):
        print(f"{i}*{j}={i*j}", end=' ')
    print("")
# Out:
# 1*1=1 1*2=2 1*3=3 1*4=4 1*5=5 1*6=6 1*7=7 1*8=8 1*9=9 1*10=10 1*11=11 1*12=12
# 2*1=2 2*2=4 2*3=6 2*4=8 2*5=10 2*6=12 2*7=14 2*8=16 2*9=18 2*10=20 2*11=22 2*12=24
# 3*1=3 3*2=6 3*3=9 3*4=12 3*5=15 3*6=18 3*7=21 3*8=24 3*9=27 3*10=30 3*11=33 3*12=36
# 4*1=4 4*2=8 4*3=12 4*4=16 4*5=20 4*6=24 4*7=28 4*8=32 4*9=36 4*10=40 4*11=44 4*12=48
# 5*1=5 5*2=10 5*3=15 5*4=20 5*5=25 5*6=30 5*7=35 5*8=40 5*9=45 5*10=50 5*11=55 5*12=60
# 6*1=6 6*2=12 6*3=18 6*4=24 6*5=30 6*6=36 6*7=42 6*8=48 6*9=54 6*10=60 6*11=66 6*12=72
# 7*1=7 7*2=14 7*3=21 7*4=28 7*5=35 7*6=42 7*7=49 7*8=56 7*9=63 7*10=70 7*11=77 7*12=84
# 8*1=8 8*2=16 8*3=24 8*4=32 8*5=40 8*6=48 8*7=56 8*8=64 8*9=72 8*10=80 8*11=88 8*12=96
# 9*1=9 9*2=18 9*3=27 9*4=36 9*5=45 9*6=54 9*7=63 9*8=72 9*9=81 9*10=90 9*11=99 9*12=108
# 10*1=10 10*2=20 10*3=30 10*4=40 10*5=50 10*6=60 10*7=70 10*8=80 10*9=90 10*10=100 10*11=110 10*12=120
# 11*1=11 11*2=22 11*3=33 11*4=44 11*5=55 11*6=66 11*7=77 11*8=88 11*9=99 11*10=110 11*11=121 11*12=132
# ...

# %% [markdown]
# Looking at the example above, two `for` loops were used. In the 1st for loop, the numbers 2 through 9 (`range(2, 10)`) are assigned to `i` in turn. When `i` is first 2, we enter the 2nd for loop. In the 2nd for loop, the numbers 1 through 9 (`range(1, 10)`) are assigned to `j`, and then the next statement `print(i*j)` runs.
#
# So when `i` is 2, `2*1`, `2*2`, `2*3`, ... `2*9` run in turn and the values are printed. Then the same thing happens when `i` is 3, and so on, until `i` is 9. The reason we set the `end` parameter on `print` like `print(i*j, end=" ")` is so the output stays on the same line instead of moving to a new line.
#
# <br><br>
# By default, the `end` parameter of `print` is set to the newline character (`\n`).
# The `print(' ')` that follows is used to separate the 2-times row, the 3-times row, and so on. After the second for loop ends, it makes the next output start on a new line.|

# %% [markdown]
# # Homework

# %% [markdown]
# Q1. Write code so that the print window shows the picture below.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q1-1. Try doing this with a for loop.

# %%
# for i in range(1,6):
#     for j in range(i):
#         print("*", end = '')
#     for k in range(12-2*i):
#         print(" ", end = '')
#     for j in range(i):
#         print("*", end = '')
#     print("")

# print("************")

# for i in range(1,6):
#     for j in range(6-i):
#         print("*", end = '')
#     for k in range(i*2):
#         print(" ", end = '')
#     for j in range(6-i):
#         print("*", end = '')
#     print("")
asterisk = ""
space = "            "
for i in range(0,6):
    asterisk += "*"
    space = space[:-2]
    print(f"{asterisk}{space}{asterisk}")
    
    
for i in range(0,6):
    asterisk = asterisk[:-1]
    space += "  "
    print(f"{asterisk}{space}{asterisk}")
# Out:
# *          *
# **        **
# ***      ***
# ****    ****
# *****  *****
# ************
# *****  *****
# ****    ****
# ***      ***
# **        **
# *          *

# %%
# Write your codes

# %% [markdown]
# Answer

# %% [markdown]
# Q2. Aimee wants to create many variables.
#
# Suppose, for example, that a group has 1000 members.
#
# <br><br>
#
# Aimee wanted to use a for loop to create 1000 variables of the form `ith_person = "Hi, i'm the ith member of the group"`, and tried the following:
#
# ```python
# ### Using f-string formatting ###
#
# for i in range(1, 1001):
#   f"{i}th_person" = f"Hi, i'm the {i}th member of the group"
# ```
#
# But she got an error saying you can't set a variable name with formatting.
#
# In other words, she wanted the variable name itself to change as `i` changes, but there's no straightforward way to auto-generate variable names like that.

# %% [markdown]
# Write code that can serve as an alternative to this idea. That is, even if you can't actually create 1000 variables with a for loop, write code that achieves a similar effect.
#
#  - Hint 1: Think back to the data types we have learned so far.
#  - Hint 2: If 1 ~ 1000 each represent 1st ~ 1000th, maybe 1 ~ 1000 can act as an id?

# %%
# Write your codes


person1 = "Hi, i'm the 1th member of the group"
person2 = "yoonsung"
person3 = "justin"

# %%
dictionary = {}
for i in range(1, 1001):
  dictionary[f"{i}th_person"] = f"Hi, i'm the {i}th member of the group."

for i in range(1,len(dictionary)):
  print(dictionary[f"{i}th_person"])
# Out:
# Hi, i'm the 1th member of the group
# Hi, i'm the 2th member of the group
# Hi, i'm the 3th member of the group
# Hi, i'm the 4th member of the group
# Hi, i'm the 5th member of the group
# Hi, i'm the 6th member of the group
# Hi, i'm the 7th member of the group
# Hi, i'm the 8th member of the group
# Hi, i'm the 9th member of the group
# Hi, i'm the 10th member of the group
# Hi, i'm the 11th member of the group
# Hi, i'm the 12th member of the group
# Hi, i'm the 13th member of the group
# Hi, i'm the 14th member of the group
# Hi, i'm the 15th member of the group
# Hi, i'm the 16th member of the group
# Hi, i'm the 17th member of the group
# Hi, i'm the 18th member of the group
# Hi, i'm the 19th member of the group
# Hi, i'm the 20th member of the group
# Hi, i'm the 21th member of the group
# Hi, i'm the 22th member of the group
# Hi, i'm the 23th member of the group
# Hi, i'm the 24th member of the group
# Hi, i'm the 25th member of the group
# ...

# %% [markdown]
# Answer

# %% [markdown]
# Q3. Write code that, given an input sentence, prints `'<sentence> is spam.'` if the sentence contains the word `'advertisement'` or `'Advertisement'`, and prints `'<sentence> is legitimate.'` if it contains neither.
#
# <example>
#
# ```
# sentence : adskflj;asd ijoipsdfus sstadvertisement__0asdal; //
#
# Print result : adskflj;asd ijoipsdfus sstadvertisement__0asdal; // is spam.
# ```

# %% [markdown]
# Answer

# %%
sentence = input()
if 'advertisement' in sentence or 'Advertisement' in sentence:
    print(sentence, "is spam.")
else:
    print(sentence, "is legitimate.")
# Out:
# uiojfre is legitimate.
