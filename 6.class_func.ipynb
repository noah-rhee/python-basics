# %% [markdown]
# # Week 6 - Class and Built-In Functions

# %% [markdown]
# **Goal 1** : Learn about classes, which are formed by combining multiple functions.
#
# **Goal 2** : Learn about the built-in functions that are most commonly used in Python.

# %% [markdown]
# ### Note

# %% [markdown]
# From Week 6 through the final exam, the **amount** of material you learn within each template will be noticeably smaller compared to the weeks up to Week 5.
#
# However, the **quality** of the material will be deeper and more challenging, so you must build the habit of trying things out yourself even more.
#
# <br><br>
# From now on, passively running the example code that came with guidelines for every topic is no longer meaningful. From start to finish, you must practice typing the code yourself, failing, retrying, failing again, and finally succeeding.<br><br>
#
# For reference, when I was studying programming I ran cells about 300 to 400 times per day on average. (Average number of cells per template in Week 1 ~ Week 5: 150)

# %% [markdown]
# ## 1.Class

# %% [markdown]
# You have probably used a calculator before. If you enter the number 3 into a calculator, then press the + sign, and then enter 4, it will show 7 as the result. If you press + again and enter 3, it will add 3 to the existing result of 7 and show 10.
#
# <br><br>In other words, the calculator must always be storing the previously calculated result somewhere in memory.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's implement this idea using the functions we learned earlier. The Python code that implements the calculator's "add" function is as follows.

# %%
result = 0

def add(num):
    global result
    result += num
    return result

print(add(3))
print(add(4))

# %% [markdown]
# The add function is a function that takes an input value, adds it to the previously calculated result, and returns it.
#
# We used the global variable `result` in order to keep the previously calculated result.

# %% [markdown]
# <br>But what if a single program needs 2 calculators? Each calculator must keep its own result, so a single add function as above cannot maintain separate results.
# <br><br>
# To solve this kind of situation, we have to make separate functions like the following.

# %%
result1 = 0
result2 = 0

def add1(num):
    global result1
    result1 += num
    return result1

def add2(num):
    global result2
    result2 += num
    return result2

print(add1(3))
print(add1(4))
print(add2(3))
print(add2(7))

# %% [markdown]
# We made two functions add1 and add2 that do the same thing, and we needed global variables result1 and result2 to keep the calculated results from each function.
#
# The output is as intended:

# %%
3
7
3
10

# %% [markdown]
# You can see that calculator 1's result has no effect on calculator 2.<br><br>But what if we need 3, 5, or 10 calculators? Are we going to add a global variable and a function each time? If we also have to add features like subtraction or multiplication for each calculator, the situation gets even more difficult.
# <br><br><br><br>
# We haven't learned classes yet, but for cases like this, using a **class** can solve the problem easily, like this:

# %%
class Calculator: # You haven't learn this yet tho...
    result = 0

    # def __init__(self):
        # self.result = 0

    def add(self, num):
        self.result += num
        return self.result

cal1 = Calculator()
cal2 = Calculator()

print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))

# %% [markdown]
# When you run the program you get the same result as when you used 2 functions.

# %%
3
7
3
10

# %% [markdown]
# The separate calculators cal1 and cal2 (in Python we call these **objects**) made from the Calculator **class** each play their own role. <br><br>And the result values of the calculators (cal1, cal2) maintain independent values, regardless of the result of the other calculator. <br><br>When you use a class, you only have to create objects even if the number of calculators grows, so unlike the case where you use functions, things become very simple. <br><br>If we want to add a subtraction feature, we can simply add a subtraction function to the Calculator class as follows.

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result

    def sub(self, num): # Newly added function
        self.result -= num
        return self.result

# %% [markdown]
# ### Class and Object

# %% [markdown]
# Look at the following picture, which best explains a class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This is a cookie mold and the cookies that were made using it.
#
# - Cookie mold -> class
# - Cookies made by the cookie mold -> object

# %% [markdown]
# The class we'll explain here is similar to the cookie mold. A **class** is a blueprint that lets you keep producing the same kind of thing (the cookie mold), and an **object** means the creation made from the class (the cookie made using the cookie mold).

# %% [markdown]
# <br><br>Objects made from a class have an important characteristic. That is, **each object has its own unique character**. <br><br>Just as poking a hole in or taking a bite out of one cookie made by the cookie mold has no effect on the other cookies, objects made from the same class do not affect one another at all.

# %% [markdown]
# The following is the simplest example of a Python class.

# %%
class Cookie:
   pass

# %% [markdown]
# The class above is a shell of a class with no functionality. But even an empty-shell class like this has the ability to create objects. Just like a "cookie mold" makes "cookies".<br><br>
#
# Objects are made from classes, and a single class can produce countless objects. The way to make an object of the Cookie class we created above is as follows.

# %%
a = Cookie()
b = Cookie()


print(a)

# %% [markdown]
# The variables `a` and `b` that received the result of `Cookie()` are the **objects**. It looks similar to using a function and receiving its return value.

# %% [markdown]
# ### Four Arithmetic Operations Class

# %% [markdown]
# Suppose a FourCal class that supports the four arithmetic operations works as follows. That is, although it won't actually run yet, let's imagine writing the code below and getting the desired result.
# <br><br>
# First, type `a = FourCal()` to create an object called `a`.

# %%
a = FourCal()

# %% [markdown]
# Then enter `a.setdata(4, 2)` to assign the numbers 4 and 2 to `a`.

# %%
a.setdata(4, 2)

# %% [markdown]
# When you run `a.add()` it returns the result of adding the two numbers (4 + 2),

# %%
print(a.add())

# %% [markdown]
# when you run `a.mul()` it returns the result of multiplying the two numbers (4 * 2),

# %%
print(a.mul())

# %% [markdown]
# when you run `a.sub()` it returns the result of subtracting the two numbers (4 - 2),

# %%
print(a.sub())

# %% [markdown]
# and when you run `a.div()` it returns the result of dividing the two numbers (4 / 2).

# %%
print(a.div())

# %% [markdown]
# Our goal is exactly to make a FourCal class that works like this.

# %% [markdown]
# ### Letting an object hold numbers

# %% [markdown]
# Now we need to make an object that has features like add, divide, multiply, and subtract.<br><br>But to make an object with such features, we first have to tell object `a` the 2 numbers that will be used for the four arithmetic operations. Let's make it so that we can assign the operands (4, 2) to the object as follows.

# %%
a.setdata(4, 2)

# %% [markdown]
# For the statement above to work, we have to modify the code as follows.

# %%
class FourCal:
    
    def setdata(self, first, second):
        self.first = first
        self.second = second

# %% [markdown]
# From the FourCal class we made earlier, we removed the `pass` statement and instead created the `setdata` function.<br><br>A function implemented inside a class is called a **method**. From now on, an internal function of a class will always be called a **method**, so remember the term.
#
# When you write a regular function, you write it like this:

# %%
def function_name(parameters):
    statements to execute
    ...

# %% [markdown]
# A **method** is no different from a regular function, except that it is contained inside a class.
#
# Let's look at the `setdata` method again:

# %%
def setdata(self, first, second):   # method parameters - what is self?
    self.first = first              # method body - there's a self here too
    self.second = second            # method body - what, here too?

# %% [markdown]
# The `setdata` method takes **3 input values as parameters: self, first, and second**. <br><br>However, unlike regular functions, the **first parameter `self`** of a method has a special meaning.
#
# Let's create object `a` and call the `setdata` method through `a` as follows.

# %%
a = FourCal()
a.setdata(4, 2)


print(a.first)

# %% [markdown]
# To call a class's method through an object, you use the dot (.) operator like `a.setdata(4, 2)`.
# <br><br>
# But isn't something a bit odd? <br><br>The `setdata` method needs **3 parameters in total: self, first, and second**, but we only **passed 2 values** like `a.setdata(4, 2)`. Why? <br><br>The reason is that when you call it like `a.setdata(4, 2)`, the object `a` that called `setdata` is automatically passed to the first parameter `self` of `setdata`. <br><br><br><br>The picture below makes it easier to understand how the values you provide when calling an object are passed to the method.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Teacher():
    def printdata(self, x , y):
        self.teacher = 'justin'
        print(f"hello {x} and {y}")

justin = Teacher()
justin.printdata('joonsung', 'yoonsung')

# %%
print(justin.teacher)

# %% [markdown]
# The first parameter of a Python method is, by convention, named `self`. The name `self` is used because the calling object itself is passed when an object calls the method.

# %% [markdown]
# ### The body of the setdata method

# %% [markdown]
# Now let's look at the body of the `setdata` method.

# %%
def setdata(self, first, second):   # method parameters
    self.first = first              # method body
    self.second = second            # method body

# %% [markdown]
# When you call it like `a.setdata(4, 2)`, the values 4 and 2 are passed to the parameters `first` and `second` of `setdata`, respectively, so the body of `setdata` is interpreted like this:

# %%
self.first = 4
self.second = 2

# %% [markdown]
# Since `self` is the object `a` that was passed in, this is again interpreted as follows.

# %%
a.first = 4
a.second = 2

# %% [markdown]
# When the statement `a.first = 4` is executed, the object variable `first` is created on object `a` and the value 4 is stored in it. Likewise, when `a.second = 2` is executed, the object variable `second` is created on object `a` and the value 2 is stored in it.
# <br><br>
# Variables that belong only to a particular object are called **object variables** (instance attributes).
#
# Let's check this as follows.

# %%
class FourCal:
    
    def setdata(self, first, second):
        self.first = first
        self.second = second

# %%
class FourCal:
    
    def setdata(self, x, y):
        self.first = x
        self.second = y

# %%
a = FourCal()
a.setdata(4, 2)

print(a.first)
print(a.second)

# %% [markdown]
# You can see that the object variables `first` and `second` were created on object `a`.
# <br><br>
# This time let's create objects `a` and `b` as follows.

# %%
a = FourCal()
b = FourCal()

# %% [markdown]
# Then create the object variable `first` of object `a` like this:

# %%
a.setdata(4, 2)
print(a.first)

# %% [markdown]
# Now create the object variable `first` of object `b` like this:

# %%
b.setdata(3, 7)
print(b.first)

# %% [markdown]
# Q. Doing the above, we confirmed that the object variable `first` of object `b` is set to 3.<br><br>So will the `first` of object `a` change to 3? Or will it keep its original value of 4?
#
# Let's check the result as follows.

# %%
print(a.first)

# %% [markdown]
# You can see that the value of `first` for object `a` is unaffected by `b`'s `first` value and keeps its original value.<br><br>The point I want to emphasize through this example is exactly this:<br><br>**The object variables of an object made from a class maintain values independently of any other object's object variables.**<br><br><br><br>Understanding this is the most important thing about classes.
#
# Below is the FourCal class as completed so far.

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

# %% [markdown]
# Did you understand well so far?

# %% [markdown]
# ### Try It! 1

# %% [markdown]
# Make an `Info` class so that an object of the class can hold `height` and `weight` as object variables.
#
# Once you've made it, put `height = 190` and `weight = 70` into a `Justin` object and verify it.

# %%
class Info:
    def data(self, height, weight):
        self.height = height
        self.weight = weight
Justin = Info()
Justin.data(190, 70)
print(Justin.height)
print(Justin.weight)
# Out:
# 190
# 70

# %% [markdown]
# ### Addition function

# %% [markdown]
# Alright! Now that we've set the 2 number values, let's add a feature that adds the 2 numbers to the class we just made. <br><br>We need to make a class with an addition feature like the following.

# %%
a = FourCal()
a.setdata(4, 2)

print(a.add())

# %% [markdown]
# Let's make the FourCal class so that this operation works.

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    # Newly added lines
    def add(self): # New method
        result = self.first + self.second
        return result

# %%
class Person:
    def naming(self):
        self.name = 'justin'

    def change_name(self, new_name):
        self.name = new_name    


teacher = Person()
teacher.naming()
print(teacher.name) 


teacher.change_name('Jacob')
print(teacher.name)

# %% [markdown]
# What's newly added is the `add` method. Now let's use the class.

# %%
a = FourCal()
a.setdata(4, 2)

# %% [markdown]
# If you call it like the above, then as we've seen before, the values 4 and 2 will be stored in object `a`'s object variables `first` and `second`.
#
# Now let's call the `add` method.

# %%
print(a.add())

# %% [markdown]
# If you call `a.add()`, the `add` method is called and the value 6 is printed. Let's separate out the `add` method to look at in detail how 6 ends up being printed.

# %%
def add(self):
    result = self.first + self.second
    return result

# %% [markdown]
# The `add` method's parameter is `self` and its return value is `result`. The part that calculates the return value `result` is as follows.

# %%
result = self.first + self.second

# %% [markdown]
# When the `add` method is executed by object `a` like `a.add()`, the object `a` is automatically passed in as `self` of `add`, so the line above is interpreted as follows.

# %%
result = a.first + a.second

# %% [markdown]
# Since `a.setdata(4, 2)` was called before `a.add()`, `a.first = 4` and `a.second = 2` are already set, so the line above is again interpreted as follows.

# %%
result = 4 + 2

# %% [markdown]
# So calling `a.add()` returns 6:

# %%
print(a.add())

# %% [markdown]
# If you understand everything up to here, you know more than 80% of classes.
#
#
# Class in Python is actually not that complicated concept!

# %% [markdown]
# ### Subtraction, multiplication and division functions

# %%
class FourCal:

    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result

    def mul(self): # Newly added method
        result = self.first * self.second
        return result

    def sub(self): # Newly added method
        result = self.first - self.second
        return result

    def div(self): # Newly added method
        result = self.first / self.second
        return result

# %% [markdown]
# `mul`, `sub`, and `div` all use the same approach as the `add` method, so I won't explain them separately.
#
# Let's verify that everything actually works correctly.

# %%
a = FourCal()
b = FourCal()
a.setdata(4, 2)
b.setdata(3, 8)

a.add()

a.mul()

a.sub()

a.div()

b.add()

b.mul()

b.sub()

b.div()

# %% [markdown]
# ### HW1. ###
#
#
#  1. Write a method that stores 292 and 400 (the names can be anything you want) into `joon` and `yoon` as object variables.
#
#  2. The moment a random number happens to equal the average of those two values, print "Hurray!" and stop. Otherwise print "Failed, one more time!" and keep going until the average is hit.
#
#  3. Also print the number of attempts it took to hit the average.

# %%
import random
rand_num = random.randint(1, 500) 

print(rand_num)

# %%
import random
class Random:
    def numbers(self, number, number1):
        self.joon = number
        self.yoon = number1
a = Random()
a.numbers(292, 400)
average = (a.joon + a.yoon) / 2
attempts = 0
correct_number = False
while correct_number == False:
    if random.randint(1,500) == average:
        correct_number = True
        print(attempts)
    else:
        attempts += 1
# Out:
# 33

# %%
import random
random.randint(1, 500)

# %% [markdown]
# ### Constructor

# %% [markdown]
# This time, let's use the FourCal class we made as follows.

# %%
a = FourCal()
a.add()

# %% [markdown]
# If you call the `add` method first on object `a` without calling `setdata`, you get an error.
#
# That's because the object variables `first` and `second` of object `a` are only created when the `setdata` method is executed.
#
# When you need to set initial values like `first` and `second` on an object, it is safer to implement a **constructor** rather than calling a method like `setdata` to set the initial values.<br><br>
#
# > A constructor is a method that is automatically called when an object is created.
#
# If you use **`__init__`** as the name of a Python method, that method becomes a **constructor**. Let's add a constructor to the FourCal class as follows.

# %%
class FourCal:
    first = x
    second = y

    # def hello(self, first, )
    def add(self):
        result = self.first + self.second
        return result

    def mul(self):
        result = self.first * self.second
        return result

    def sub(self):
        result = self.first - self.second
        return result

    def div(self):
        result = self.first / self.second
        return result

# %%
class FourCal:

    def __init__(self, first, second): # Newly added initializer
        self.first = first
        self.second = second

    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result

    def mul(self):
        result = self.first * self.second
        return result

    def sub(self):
        result = self.first - self.second
        return result

    def div(self):
        result = self.first / self.second
        return result

# %%
# a = FourCal()
# a.setdata(2, 4)
# a.add()

# ->

a = FourCal(2, 4)
a.add()

# %% [markdown]
# Let's separate out the newly added `__init__` constructor method and look at it.

# %%
def __init__(self, first, second):
    self.first = first
    self.second = second

# %% [markdown]
# The `__init__` method is identical to `setdata` in everything except the name.
#
# However, because we used `__init__` as the method name, it is recognized as a constructor and is **automatically called** at the moment an object is created.
#
# Now let's run the example as follows.

# %%
a = FourCal()

# %% [markdown]
# When `a = FourCal()` is run, the constructor `__init__` is called and the above error occurs.
#
# The error happens because no values were passed for the constructor's parameters `first` and `second`.
# <br><br>
# To fix the error above, you have to create the object by passing values for `first` and `second` as follows.

# %%
a = FourCal(4, 2)

# %% [markdown]
# When you do this, the parameters of the `__init__` method receive the following values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Remember that, just like other methods, the `__init__` method's first parameter `self` is automatically given the object being created.
#
# So when `__init__` is called, the object variables `first` and `second` will be created, just like when `setdata` was called.
#
# Let's check the values of the object variables as follows.

# %%
a = FourCal(4, 2)
print(a.first)

#print(a.second)

# %% [markdown]
# Let's also check that methods like `add` and `div` work properly.

# %%
a = FourCal(4, 2)
a.add()

#a.div()

# %% [markdown]
# ### (Advanced) Inheritance

# %% [markdown]
# Inheritance is when, while making one class, you let it inherit features from another class.
# <br><br>This time, let's use the concept of inheritance to add a feature to the FourCal class that computes a^b (a to the power of b).
# <br><br>
# Since we already made the FourCal class earlier, we can easily make a `MoreFourCal` class that inherits from FourCal as follows.

# %%
class MoreFourCal(FourCal): # See what is between arrow heads
    pass

# %% [markdown]
# To inherit from a class, you put the **name of the class to inherit** in parentheses after the class name, like this:
#
# > class ClassName(ClassToInherit)
#
# Since `MoreFourCal` inherits from FourCal, it should be able to use all of FourCal's features.
#
# Let's check this as follows.

# %%
a = MoreFourCal(4, 2)

print(a.first)

a.add()

#a.mul()

#a.sub()

#a.div()

# %% [markdown]
# Now let's make the `MoreFourCal` class that calculates a to the power of b (a^b), which was the original goal.

# %%
class MoreFourCal(FourCal):

    def pow(self): # Newly added method
        result = self.first ** self.second
        return result

# %% [markdown]
# We removed the `pass` statement and added the `pow` method that computes the power of two numbers as above. Then let's run the `pow` method as follows.

# %%
a = MoreFourCal(4, 2)
a.pow()

#a.add()

# %% [markdown]
# If we set the values 4 and 2 on the `a` object made from the `MoreFourCal` class and call the `pow` method, we can see that it returns 16, which is 4 to the power of 2 (4^2). The inherited `add` method also works correctly.
# <br><br>
# Inheritance is mainly used to extend the features of a class while leaving the existing class (FourCal) untouched, like the `MoreFourCal` class.

# %% [markdown]
# ### Method Overriding

# %% [markdown]
# This time, let's run the FourCal class as follows.

# %%
a = FourCal(4, 0)
a.div()

# %% [markdown]
# If you set values 4 and 0 on object `a` of the FourCal class and call the `div` method, it tries to divide 4 by 0, so the ZeroDivisionError shown above occurs.<br><br>But what if you want it to return 0 instead of an error when dividing by 0?
#
# Let's make a `SafeFourCal` class that inherits from FourCal as follows.

# %%
class SafeFourCal(FourCal):

    def div(self):
        if self.second == 0:  # If the divisor is 0, modify it to return 0
            return 0
            
        else:
            return self.first / self.second

# %% [markdown]
# While making the `SafeFourCal` class, we rewrote the `div` method that we inherited from FourCal. This is **overriding**.
# <br><br>
# The `div` method we overrode in the `SafeFourCal` class was modified to return 0 when the divisor is 0. Now let's run the previous example again, using `SafeFourCal` instead of `FourCal`.

# %%
a = SafeFourCal(4, 0)

a.div()

# %% [markdown]
# Unlike the FourCal class, no ZeroDivisionError occurs and you can see that 0 is returned as intended.

# %% [markdown]
# ### Try It! 2

# %% [markdown]
# Modify the `Info` class from Try It! 1 so that it uses the `__init__` method.

# %%
class Info:
    def __init__(self, height, weight):
        self.height = height
        self.weight = weight

Justin = Info(190, 70)

# %% [markdown]
# Now, while making an `InfoPrinter` class that inherits from the modified `Info` class, add a **printer** method that prints `height` and `weight`.

# %%
class InfoPrinter(Info):
    def printer(self):
        print(self.height)
        print(self.weight)

Justin.printer()
# Out:
# 190
# 70

# %% [markdown]
# To check, create a `Justin` object by passing 190 and 70 as arguments to the `InfoPrinter` class, and then run the `printer` method.

# %%
Justin = InfoPrinter(190, 70)
Justin.printer()
# Out:
# 190
# 70

# %% [markdown]
# ## 2.Built-In Functions

# %% [markdown]
# Thanks to Python's built-in functions, we can pick from basic functions instead of having to code the feature we want every time.
#
# We've already learned a few built-in functions: `print`, `del`, `type`, and so on.
#
# <br><br>
# I've picked only the truly important and frequently used built-in functions, so make sure you learn them well.

# %% [markdown]
# ### abs

# %% [markdown]
# `abs(x)` is a function that returns the absolute value of a given number.

# %%
abs(-3)

def noahabs(integer):
    if isinstance(integer, int) == True:
        if integer < 0:
            result = -integer
        else:
            result = integer
    else:
        print("This is not an integer.")
    print(result)

noahabs(-234)
# Out:
# 234

# %% [markdown]
# ### all

# %% [markdown]
# `all(x)` takes iterable data `x` as input. It returns `True` if all elements of `x` are true, and `False` if even one of them is false.
#
# Iterable data means a data type that can be used in a for loop. Lists, tuples, strings, dictionaries, and sets are examples.
#
# Look at the following example.

# %%
all( [1, 2, 3, 0] )

# %%
all((True, False, True, True, True))

def noahall(a):
    if isinstance(a,list) == True or isinstance(a,tuple) == True or isinstance(a,dict) == True:
        if False in a:
            return False
    else:
        return True

noahall([True, True, False])
# Out:
# False

# %% [markdown]
# ### any

# %% [markdown]
# `any(x)` takes iterable data `x` as input and returns `True` if any one element of `x` is true, and returns `False` only when all elements of `x` are false. It is the opposite of `all(x)`.
#
# Look at the following example.

# %%
any([0, ""])

def noahany(a):
    if isinstance(a,list) == True or isinstance(a,tuple) == True or isinstance(a,dict) == True:
        if True in a:
            return True
    else:
        return False

noahany([True, True, False])
# Out:
# True

# %% [markdown]
# ### chr

# %% [markdown]
# `chr(i)` is a function that takes a Unicode integer value and returns the character corresponding to that code.
#
# Unicode is an industry standard designed so that all characters in the world can be represented and handled consistently on computers.

# %%
chr(122)
# Out:
# 'z'

# %%
chr(97)

# %% [markdown]
# ### ord

# %% [markdown]
# `ord(c)` is a function that returns the Unicode integer value of a character.
#
# The `ord` function is the opposite of the `chr` function.

# %%
ord('a')
# Out:
# 97

# %% [markdown]
# ### divmod

# %% [markdown]
# `divmod(a, b)` takes 2 numbers as input and is a function that returns the quotient and remainder of `a` divided by `b` as a tuple.

# %%
divmod(7, 3)

def noahdivmod(a,b):
    tup = (a//b, a%b)
    return tup
noahdivmod(7,3)
# Out:
# (2, 1)

# %% [markdown]
# ### (Advanced) enumerate

# %% [markdown]
# `enumerate` means "to enumerate". This function takes ordered data (list, tuple, string) as input and returns an enumerate object that includes index values.
#
# Typically `enumerate` is used together with a for loop, like in the example below.
#
# Look at the following example.

# %%
# for i, name in [ (0, 'body'), (1, 'foo'), (2, 'bar') ]: # ['body', 'foo', 'bar']
def noahenumerate(a):
    l = []
    for i in range(len(a)):
        l.append((i, a[i]))
    return l

noahenumerate(['body', 'foo', 'bar'])
# Out:
# [(0, 'body'), (1, 'foo'), (2, 'bar')]

# %%
x = []

# %% [markdown]
# `body`, `foo`, and `bar` were printed in order along with their index values. In other words, when you use `enumerate` together with a for loop as in the example above, you can easily get the current order (index) and value of a sequence.
#
# When you need an index value telling you the current position of an object inside a repeating section like a for loop, the `enumerate` function is very useful.

# %% [markdown]
# ### Try It! 1

# %% [markdown]
# ```Li = ['Python', 'Java', 'JavaScript', 'R']``` is the list.
#
# Using the `Li` variable and `enumerate`, write code that produces the output shown below.
#
# ![image.png](data:image/png;base64,...)

# %%
for i in [1, 2, 3, 4]:
    print(i)

# %%
for i, name in enumerate(['Python', 'Java', 'JavaScript', 'R']):
    print(f"Element number {i + 1} is {name}.")
# Out:
# Element number 1 is Python.
# Element number 2 is Java.
# Element number 3 is JavaScript.
# Element number 4 is R.

# %% [markdown]
# ### (Advanced) zip

# %% [markdown]
# `zip(*iterable)` is a function that pairs together data of equal length and returns the result.
#
# The `*iterable` here means that you can pass in multiple iterable data items.
#
# Let's see how it's used through the following example.

# %%
list(zip( [1, 2, 3], [4, 5, 6], [7, 8, 9] ))

def noahzip(l):
    for i in range(len(l)):
        
# print( list(map(lambda x: x**2, [1, 5, 6, 9])) )


# list(zip("abc", "def"))
# Out:
# [(1, 4, 7), (2, 5, 8), (3, 6, 9)]

# %%
[ ['jacob', 'justin', 'jiwan'], ['eva', 'elsa', 'chloe'], ['cristina', 'ariana', 'Cardi B'] ]
# Out:
# [['jacob', 'justin', 'jiwan'],
#  ['eva', 'elsa', 'chloe'],
#  ['cristina', 'ariana', 'Cardi B']]

# %% [markdown]
# ### eval

# %% [markdown]
# `eval(expression)` is a function that takes an expression in the form of a string as input and returns the result of evaluating that string.

# %%
eval('1+2')

def noaheval(s):
    for i in s:
        

# eval('divmod(4, 3)')
# Out:
# 3

# %% [markdown]
# ### int

# %% [markdown]
# `int(x)` is a function that returns the integer form of a string-formatted number or a number with a decimal point. If an integer is passed in, it returns it unchanged.

# %%
int('3')

# %% [markdown]
# ### str

# %% [markdown]
# `str(object)` is a function that converts an object into string form and returns it.

# %%
str(3)

# %% [markdown]
# ### len

# %% [markdown]
# `len(s)` is a function that returns the length (the total number of elements) of the input value `s`.

# %%
len("python")

# %% [markdown]
# ### list

# %% [markdown]
# `list(iterable)` is a function that takes an iterable as input and returns a list made from it.

# %%
list("python")

# list((1,2,3))

# %% [markdown]
# ### map

# %% [markdown]
# `map(f, iterable)` takes a function `f` and an iterable as inputs. The `map` function applies the function `f` to each element of the input iterable and returns the result.
#
# Look at the following example.

# %%
def two_times(numberList):
    result = []
    for number in numberList:
        result.append(number*2)
    return result

result = two_times([1, 2, 3, 4])
print(result)

print(list(map(two_times,[1,2,43,4])))
# Out:
# [2, 4, 6, 8]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 10
#       6
#       7 result = two_times([1, 2, 3, 4])
#       8 print(result)
#       9
# ---> 10 print(list(map(two_times,[1,2,43,4])))
#
# Cell In[31], line 3, in two_times(numberList)
#       1 def two_times(numberList):
#       2     result = []
# ----> 3     for number in numberList:
#       4         result.append(number*2)
#       5     return result
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# `two_times` is a function that takes a list and returns a list with each element multiplied by 2. The result of running it is as follows.
#
# Result: `[2, 4, 6, 8]`
#
# The example above can be rewritten using the `map` function as follows.

# %%
def two_times(x): 
    return x*2

list(     map(two_times, [1, 2, 3, 4])        )
# Out:
# [2, 4, 6, 8]

# %%
[ [1, 2, 3, 4, 5], [2,41,35,1,51,35,1] , [124,12,41,24,124,12] ]

[5, 51, 124]
# Out:
# [5, 51, 124]

# %% [markdown]
# Let's interpret this example.
#
# First, the first element of the list, 1, is passed in as the input of the `two_times` function and goes through 1 * 2 to become 2.
#
# Next, the second element of the list, 2, goes through 2 * 2 and becomes 4. So the result becomes `[2, 4]`. When all 4 elements have been processed, it becomes `[2, 4, 6, 8]`. This is what the `map` function does.<br><br>
#
# In the example above we used `list` to print the result of `map` as a list. (The `map` function returns a `map` object.)
#
# The previous example can be made even shorter using `lambda` as follows.

# %%
list(map(lambda a: a*2, [1, 2, 3, 4]))

# %% [markdown]
# ### Try It! 2

# %% [markdown]
# Suppose you have a nested list ```N_Li = [[1,2,3,4,5], [23,4,2354], ['a']]```. Using the `map` function, print a list showing the lengths of the elements of `N_Li` like this:
#
# [5, 3, 1]

# %%
N_Li = [[1,2,3,4,5], [23,4,2354], ['a']]

list(map(len, N_Li))

# %% [markdown]
# ### max

# %% [markdown]
# `max(iterable)` is a function that takes iterable data as its argument and returns its maximum value.

# %%
max([1, 2, 3])

# %% [markdown]
# ### min

# %% [markdown]
# `min(iterable)`, the opposite of `max`, is a function that takes iterable data as its argument and returns its minimum value.

# %%
min([1, 2, 3])

# %% [markdown]
# ### range

# %% [markdown]
# `range([start,] stop [,step])` is a function frequently used together with the for loop. This function takes the input numbers and returns the corresponding range of values as an iterable object.

# %%
list(range(0, -10, -1))

# %% [markdown]
# ### round

# %% [markdown]
# `round(number[, ndigits])` is a function that takes a number, rounds it, and returns the result.
#
# > `[, ndigits]` means that `ndigits` may or may not be present.

# %%
round(4.2)

# %% [markdown]
# ### sorted

# %% [markdown]
# `sorted(iterable)` is a function that sorts the input data and returns the result as a list.

# %%
print(sorted("zero"))

# %% [markdown]
# Lists also have a `sort` function. However, the list's `sort` function only sorts the list object itself in place; it does not return the sorted result.

# %% [markdown]
# ### sum

# %% [markdown]
# `sum(iterable)` is a function that returns the sum of the input data.

# %%
sum((4,5,6))

# %% [markdown]
# ### type

# %% [markdown]
# `type(object)` is a function that tells you what data type the input value is.

# %%
type([ ])

# %% [markdown]
# # Homework

# %% [markdown]
# ### Problem 1.

# %% [markdown]
# Let's create a class named **MultiFuncs**.
#
# MultiFuncs should have the following properties:
#
# <br>
#
# - It has only one method, `FourCal()`.
#
# - The MultiFuncs class should use a constructor so that, at the moment an object is created, the two numbers passed inside the class's `()` are set as instance variables (object variables).
#
# - `FourCal()` is a method that, for the two numbers stored as instance variables when the object was created, prints the results of all four arithmetic operations.
#
# <br>
# <br>
#
# Hint: remember that you need to include `self` as a parameter every time you define a method. `self` must also be used when assigning the two input numbers to the instance variables.
#
#
# <br><br>
#
# That is, when you write the code as below, the result should look like this.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Student's solution

# %%
class MultiFuncs:
  def __init__(self, a,b):
    self.a = a
    self.b = b
  
  def FourCal(self):
    print(f"{self.a} + {self.b} = {self.a+self.b}")
    print(f"{self.a} - {self.b} = {self.a-self.b}")
    print(f"{self.a} * {self.b} = {self.a*self.b}")
    print(f"{self.a} / {self.b} = {self.a/self.b}")

  # Write further code







# Check if your code has no problem at all

obj = MultiFuncs(50, 10)
obj.FourCal()

#obj = MultiFuncs(20, 80)
#obj.FourCal()
# Out:
# 50 + 10 = 60
# 50 - 10 = 40
# 50 * 10 = 500
# 50 / 10 = 5.0

# %% [markdown]
# Teacher's solution

# %% [markdown]
# ### Problem 2.

# %% [markdown]
# Looking at the MultiFuncs class defined above, we now want to add a `Maxima` method that finds the maximum of given numbers, and a `Mean` method that finds the average.
#
# Write a new class `FultiFuncs2` with the above features added.
# <br><br>
#
# - You may NOT copy/paste MultiFuncs' methods — you must use inheritance.
#
# - The two newly added methods should `print()` their results.
#
# - Including the `FourCal` method, the class should support a total of three operations.
#
# - You know, manual counting is always banned!
#
# <br><br>
# That is, when you write the code as below, the result should look like this.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Student's solution

# %%
class MultiFuncs2(MultiFuncs):
    def Maxima(self,l):
        new_l = sorted(l)
        print(f"The maximum of the list is {new_l[-1]}")
    
    def Mean(selfl,l):
        print(f"The mean of the list is {sum(l) / len(l)}")














# Validate your class

obj2 = MultiFuncs2(30, 4)
obj2.FourCal()
obj2.Maxima([10, 90, 65, 25, 40])
obj2.Mean([70, 10, 25, 5, 44, 1.5])
# Out:
# 30 + 4 = 34
# 30 - 4 = 26
# 30 * 4 = 120
# 30 / 4 = 7.5
# The maximum of the list is 90
# The mean of the list is 25.916666666666668

# %% [markdown]
# Teacher's solution

# %% [markdown]
# ### Problem 3 (Challenging Problem).

# %% [markdown]
# * This problem assumes that you have already written the correct solution up through Problem 2.
#
# At last, we have completed the desired `MultiFuncs2` class.
#
# As we saw above, when you give it numbers or a list of numbers, it produces the desired result.
#
#
#
# <br><br>
# Since you can make multiple objects from a single class, in order to compare the averages of ```[70, 10, 25, 5, 44, 1.5]``` and ```[10, 90, 65, 25, 40]```, I wrote the following code.

# %%
obj1 = MultiFuncs2(0, 0) # Since we don't use the FourCal method, the values of the object variables can be anything.
obj1.Maxima([70, 10, 25, 5, 44, 1.5])

obj2 = MultiFuncs2(0, 1) # Since we don't use the FourCal method, the values of the object variables can be anything.
obj2.Maxima([10, 90, 65, 25, 40])

# %% [markdown]
# Since each statement is ultimately a Python string, I tried storing them in `Max1` and `Max2` and comparing the two. Then the following problem occurred.

# %%
obj1 = MultiFuncs2(0, 0) 
Max1 = obj1.Maxima([70, 10, 25, 5, 44, 1.5])

obj2 = MultiFuncs2(0, 1) 
Max2 = obj2.Maxima([10, 90, 65, 25, 40])

Max1 > Max2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 obj1 = MultiFuncs2(0, 0)
#       2 Max1 = obj1.Maxima([70, 10, 25, 5, 44, 1.5])
#       3
#       4 obj2 = MultiFuncs2(0, 1)
#
# NameError: name 'MultiFuncs2' is not defined

# %% [markdown]
# 1. It says that `>` cannot be used. That's because two sentences cannot be compared. The reason is that when we wrote the `Maxima` method, we used the string data type rather than the number data type.
#
# 2. But it turns out that, according to the error message, `Max1` and `Max2` aren't even strings; they are NoneType.
#
# In other words, simply calling the method printed correctly, but **when we tried to store the result in a variable, something went wrong and an empty type called `None` got stored**.

# %% [markdown]
# <br><br><br>
# By using overriding on the MultiFuncs2 class,
#
# modify it so that ① it returns plain numbers (values) instead of strings, and ② it returns the values (so that we can put the outputs of methods into variables) instead of printing them.
#
# -> Create the overridden **MultiFuncs3 class**.
# <br><br>
# **Hint**: this problem only needs exactly one line of code; if you review the function part from Week 4, it's a very easy problem.
#
#
# <br><br>
# <Example output>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Student's solution

# %%
class MultiFuncs3(MultiFuncs2):

  def Maxima(self, myList):
      
    # One-liner solution
      return sorted(myList)[-1]


# Validate yours

obj3 = MultiFuncs3(0, 0) 
Max1 = obj3.Maxima([70, 10, 25, 5, 44, 1.5])

obj4 = MultiFuncs3(0, 1) 
Max2 = obj4.Maxima([10, 90, 65, 25, 40])

Max1 > Max2
# Out:
# False

# %% [markdown]
# Teacher's solution
